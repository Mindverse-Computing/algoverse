# %% [markdown]
# Certainly! Here's a comprehensive table listing each problem from the "Blind 75" coding interview questions, organized by category. For each problem, I've included the problem number, title, difficulty level, applicable methods implemented, and space and time complexity.
#
# **1. Arrays**
#
# | No. | Problem                                         | Difficulty | Applicable Methods             | Time Complexity | Space Complexity |
# |-----|-------------------------------------------------|------------|-------------------------------|-----------------|------------------|
# | 1   | Two Sum                                         | Easy       | Hash Map                      | O(n)            | O(n)             |
# | 2   | Best Time to Buy and Sell Stock                 | Easy       | Dynamic Programming           | O(n)            | O(1)             |
# | 3   | Contains Duplicate                              | Easy       | Hash Set                      | O(n)            | O(n)             |
# | 4   | Product of Array Except Self                    | Medium     | Prefix Product, Suffix Product| O(n)            | O(1)             |
# | 5   | Maximum Subarray                                | Easy       | Kadane's Algorithm            | O(n)            | O(1)             |
# | 6   | Maximum Product Subarray                        | Medium     | Dynamic Programming           | O(n)            | O(1)             |
# | 7   | Find Minimum in Rotated Sorted Array            | Medium     | Binary Search                 | O(log n)        | O(1)             |
# | 8   | Search in Rotated Sorted Array                  | Medium     | Binary Search                 | O(log n)        | O(1)             |
# | 9   | 3Sum                                            | Medium     | Two Pointers, Sorting         | O(n^2)          | O(n)             |
# | 10  | Container With Most Water                       | Medium     | Two Pointers                  | O(n)            | O(1)             |
#
# **2. Strings**
#
# | No. | Problem                                         | Difficulty | Applicable Methods             | Time Complexity | Space Complexity |
# |-----|-------------------------------------------------|------------|-------------------------------|-----------------|------------------|
# | 11  | Longest Substring Without Repeating Characters  | Medium     | Sliding Window, Hash Map      | O(n)            | O(min(n, m))     |
# | 12  | Longest Repeating Character Replacement         | Medium     | Sliding Window, Hash Map      | O(n)            | O(1)             |
# | 13  | Minimum Window Substring                        | Hard       | Sliding Window, Hash Map      | O(n)            | O(m + n)         |
# | 14  | Valid Anagram                                   | Easy       | Sorting, Hash Map             | O(n log n)      | O(1)             |
# | 15  | Group Anagrams                                  | Medium     | Hash Map                      | O(n * k log k)  | O(n)             |
# | 16  | Valid Parentheses                               | Easy       | Stack                         | O(n)            | O(n)             |
# | 17  | Longest Palindromic Substring                   | Medium     | Dynamic Programming, Expand Around Center | O(n^2) | O(n^2) or O(1) |
# | 18  | Palindromic Substrings                          | Medium     | Dynamic Programming, Expand Around Center | O(n^2) | O(n^2) or O(1) |
# | 19  | Decode Ways                                     | Medium     | Dynamic Programming           | O(n)            | O(n)             |
# | 20  | Longest Common Subsequence                      | Medium     | Dynamic Programming           | O(n * m)        | O(n * m)         |
#
# **3. Linked Lists**
#
# | No. | Problem                                         | Difficulty | Applicable Methods             | Time Complexity | Space Complexity |
# |-----|-------------------------------------------------|------------|-------------------------------|-----------------|------------------|
# | 21  | Reverse Linked List                             | Easy       | Iterative, Recursive          | O(n)            | O(1) or O(n)     |
# | 22  | Detect Cycle in a Linked List                   | Easy       | Two Pointers (Floyd’s Cycle Detection) | O(n) | O(1) |
# | 23  | Merge Two Sorted Lists                          | Easy       | Iterative, Recursive          | O(n + m)        | O(1) or O(n + m) |
# | 24  | Remove Nth Node From End of List                | Medium     | Two Pointers                  | O(n)            | O(1)             |
# | 25  | Reorder List                                    | Medium     | Two Pointers, Reversing       | O(n)            | O(1)             |
#
# Certainly! Continuing with the comprehensive table of the "Blind 75" coding interview questions, organized by category, here are the remaining categories:
#
# **4. Trees and Graphs**
#
# | No. | Problem                                         | Difficulty | Applicable Methods             | Time Complexity | Space Complexity |
# |-----|-------------------------------------------------|------------|-------------------------------|-----------------|------------------|
# | 26  | Invert Binary Tree                              | Easy       | Recursive, Iterative          | O(n)            | O(h)             |
# | 27  | Maximum Depth of Binary Tree                    | Easy       | Recursive, Iterative          | O(n)            | O(h)             |
# | 28  | Same Tree                                       | Easy       | Recursive, Iterative          | O(n)            | O(h)             |
# | 29  | Subtree of Another Tree                         | Easy       | Recursive                     | O(m * n)        | O(h)             |
# | 30  | Lowest Common Ancestor of a Binary Search Tree  | Easy       | Recursive, Iterative          | O(h)            | O(h)             |
# | 31  | Binary Tree Level Order Traversal               | Medium     | Breadth-First Search          | O(n)            | O(n)             |
# | 32  | Validate Binary Search Tree                     | Medium     | Recursive, Iterative          | O(n)            | O(h)             |
# | 33  | Kth Smallest Element in a BST                   | Medium     | Inorder Traversal             | O(h + k)        | O(h)             |
# | 34  | Construct Binary Tree from Preorder and Inorder Traversal | Medium | Recursive | O(n) | O(n) |
# | 35  | Binary Tree Maximum Path Sum                    | Hard       | Recursive                     | O(n)            | O(h)             |
# | 36  | Serialize and Deserialize Binary Tree           | Hard       | Recursive, Iterative          | O(n)            | O(n)             |
# | 37  | Binary Tree Right Side View                     | Medium     | Breadth-First Search          | O(n)            | O(n)             |
# | 38  | Clone Graph                                     | Medium     | Depth-First Search, Breadth-First Search | O(n + m) | O(n) |
# | 39  | Course Schedule                                 | Medium     | Depth-First Search, Topological Sort | O(n + m) | O(n) |
# | 40  | Number of Islands                               | Medium     | Depth-First Search, Breadth-First Search | O(n * m) | O(n * m) |
# | 41  | Graph Valid Tree                                | Medium     | Depth-First Search, Union-Find | O(n + m) | O(n) |
# | 42  | Word Search                                     | Medium     | Backtracking                  | O(n * m * 4^l)  | O(l)             |
# | 43  | Word Search II                                  | Hard       | Backtracking, Trie            | O(n * m * 4^l)  | O(l)             |
# | 44  | Alien Dictionary                                | Hard       | Topological Sort, Graph Traversal | O(n + m) | O(n) |
#
# **5. Dynamic Programming**
#
# | No. | Problem                                         | Difficulty | Applicable Methods             | Time Complexity | Space Complexity |
# |-----|-------------------------------------------------|------------|-------------------------------|-----------------|------------------|
# | 45  | Climbing Stairs                                 | Easy       | Dynamic Programming           | O(n)            | O(1)             |
# | 46  | Coin Change                                     | Medium     | Dynamic Programming           | O(amount * n)   | O(amount)        |
# | 47  | Longest Increasing Subsequence                  | Medium     | Dynamic Programming, Binary Search | O(n log n) | O(n) |
# | 48  | Combination Sum                                 | Medium     | Backtracking                  | O(2^n)          | O(target)        |
# | 49  | House Robber                                    | Medium     | Dynamic Programming           | O(n)            | O(1)             |
# | 50  | House Robber II                                 | Medium     | Dynamic Programming           | O(n)            | O(1)             |
# | 51  | Decode Ways                                     | Medium     | Dynamic Programming           | O(n)            | O(n)             |
# | 52  | Unique Paths                                    | Medium     | Dynamic Programming           | O(m * n)        | O(m * n)         |
# | 53  | Jump Game                                       | Medium     | Greedy, Dynamic Programming   | O(n)            | O(1)             |
# | 54  | Word Break                                      | Medium     | Dynamic Programming           | O(n * m)        | O(n)             |
#
# **6. Binary**
#
# | No. | Problem                                         | Difficulty | Applicable Methods             | Time Complexity | Space Complexity |
# |-----|-------------------------------------------------|------------|-------------------------------|-----------------|------------------|
# | 55  | Sum of Two Integers                             | Medium     | Bit Manipulation              | O(1)            | O(1)             |
# | 56  | Number of 1 Bits                                | Easy       | Bit Manipulation              | O(1)            | O(1)             |
# | 57  | Counting Bits                                   | Easy       | Dynamic Programming, Bit Manipulation | O(n) | O(n) |
# | 58  | Missing Number                                  | Easy       | Bit Manipulation, Math        | O(n)            | O(1)             |
# | 59  | Reverse Bits                                    | Easy       | Bit Manipulation              | O(1)            | O(1)             |
#
# **7. Intervals**
#
# | No. | Problem                                         | Difficulty | Applicable Methods             | Time Complexity | Space Complexity |
# |-----|-------------------------------------------------|------------|-------------------------------|-----------------|------------------|
# | 60  | Insert Interval                                 | Medium     | Sorting, Merging              | O(n)            | O(n)             |
# | 61  | Merge Intervals                                 | Medium     | Sorting, Merging              | O(n log n)      | O(n)             |
# | 62  | Non-overlapping Intervals                       | Medium     | Greedy, Sorting               | O(n log n)      | O(1)             |
# | 63  | Meeting Rooms                                   | Easy       | Sorting                       | O(n log n)      | O(n)             |
# | 64  | Meeting Rooms II                                | Medium     | Sorting, Min-Heap             | O(n log n)      | O(n)             |
#
#
#
# **8. Matrix**
#
# | No. | Problem               | Difficulty | Applicable Methods | Time Complexity | Space Complexity |
# |-----|-----------------------|------------|--------------------|-----------------|------------------|
# | 65  | Set Matrix Zeroes     | Medium     | Matrix Traversal   | O(m * n)        | O(1)             |
# | 66  | Spiral Matrix         | Medium     | Simulation         | O(m * n)        | O(1)             |
# | 67  | Rotate Image          | Medium     | Matrix Rotation    | O(n^2)          | O(1)             |
# | 68  | Word Search           | Medium     | Backtracking       | O(m * n * 4^l)  | O(l)             |
#
# **9. Heap/Priority Queue**
#
# | No. | Problem                 | Difficulty | Applicable Methods | Time Complexity | Space Complexity |
# |-----|-------------------------|------------|--------------------|-----------------|------------------|
# | 69  | Merge k Sorted Lists    | Hard       | Min-Heap           | O(N log k)      | O(k)             |
# | 70  | Top K Frequent Elements | Medium     | Min-Heap, HashMap  | O(n log k)      | O(n + k)         |
# | 71  | Find Median from Data Stream | Hard  | Two Heaps          | O(log n)        | O(n)             |
#
# **10. Miscellaneous**
#
# | No. | Problem                                 | Difficulty | Applicable Methods       | Time Complexity | Space Complexity |
# |-----|------------------------------------------|------------|--------------------------|-----------------|------------------|
# | 72  | Letter Combinations of a Phone Number    | Medium     | Backtracking             | O(4^n)          | O(n)             |
# | 73  | Generate Parentheses                     | Medium     | Backtracking             | O(4^n / √n)     | O(n)             |
# | 74  | Trapping Rain Water                      | Hard       | Two Pointers, Stack      | O(n)            | O(1)             |
# | 75  | Minimum Path Sum                         | Medium     | Dynamic Programming      | O(m * n)        | O(1)             |
#
# This completes the comprehensive table of the "Blind 75" coding interview questions, organized by category, with details on applicable methods, time complexity, and space complexity.                          |
